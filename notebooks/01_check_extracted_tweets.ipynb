# %%
from src.helpers import load_df_tweets
import numpy as np
df = load_df_tweets()
print(df.shape)
df.groupby(['user_screen_name']).agg({'created_at': [np.min,np.max,len]})
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████| 69867/69867 [00:00<00:00, 161414.37it/s]
# (69867, 36)
#                                 created_at
#                                       amin                      amax   len
# user_screen_name
# APompliano       2021-02-14 00:53:11+00:00 2021-05-03 20:10:17+00:00  3249
# BarrySilbert     2017-07-27 03:02:34+00:00 2021-05-03 17:45:46+00:00  3231
# CryptoBrekkie    2019-11-25 02:27:37+00:00 2020-07-18 16:37:35+00:00     3
# CryptoCobain     2021-03-16 06:33:21+00:00 2021-05-03 20:35:29+00:00  3245
# CryptoEuclid     2021-03-05 18:26:13+00:00 2021-05-02 20:27:46+00:00  3249
# CryptoWendyO     2021-03-06 21:57:00+00:00 2021-05-03 22:03:16+00:00  3236
# ErikVoorhees     2020-09-20 18:20:32+00:00 2021-05-03 17:05:01+00:00  3249
# EuclidAndOaks    2018-01-09 01:41:13+00:00 2021-04-17 05:01:26+00:00   843
# FEhrsam          2011-06-12 19:35:24+00:00 2021-04-30 16:07:28+00:00  1422
# ...
