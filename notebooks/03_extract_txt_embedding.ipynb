# %%
from sentence_transformers import SentenceTransformer
from src.paths import LOCAL_PROCESSED_DATA_PATH
from tqdm._tqdm_notebook import tqdm_notebook
import pandas as pd
tqdm_notebook.pandas()

model = SentenceTransformer('stsb-mpnet-base-v2')

df_path = LOCAL_PROCESSED_DATA_PATH / 'tweets_with_mentioned_coins.json'
df = pd.read_json(df_path, orient='index')
print(df.shape)
df.head(1).T
# Out:
# (90067, 37)
#                                                                            0
# created_at                                               2021-05-02 23:35:51
# id                                                       1389000716832944141
# id_str                                                   1389000716832944128
# full_text                  "taproot": {\n      "type": "bip9",\n      "bi...
# truncated                                                              False
# display_text_range                                                  [0, 267]
# entities                   {'hashtags': [], 'symbols': [], 'user_mentions...
# source                     <a href="https://about.twitter.com/products/tw...
# in_reply_to_status_id                                  1388928544000000000.0
# in_reply_to_status_id_str                              1388928544000000000.0
# in_reply_to_user_id                                             1469101279.0
# ...

# %%
df['full_text_embedding'] = df.full_text.progress_apply(model.encode)
# Out:
#   0%|          | 0/90067 [00:00<?, ?it/s]

# %%
df['created_at_trunc_h'] = df.created_at.dt.floor('h')

# %%
df_path = LOCAL_PROCESSED_DATA_PATH / 'tweets_with_embeddings.pkl'
df.to_pickle(df_path)
